# %% [markdown]
# ### Access to the application manager
# http://localhost:8080

# %% [markdown]
# ### To install new packages in the JupyterLab environment.
# Use the following command:
# !mamba install -y <package>

# %%
import sys
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
        .master("spark://spark-cluster-master:7077")
        .appName("JupyterLabPySparkStandaloneMode")
        # limit the whole application to 12 cores
        .config("spark.cores.max", "12")
        # each executor will get 3 cores → up to 4 executors (12 / 3)
        .config("spark.executor.cores", "3")
        # memory settings stay the same
        .config("spark.executor.memory", "1g")
        .config("spark.driver.cores","2")
        .getOrCreate()
)
print("Spark Version: ", spark.version)
print("Python Spark workers version: ", spark.sparkContext.pythonVer)
print("Python Spark driver version: ", sys.version)

# %%
data = [("Alice", 29), ("Bob", 35), ("Cathy", 23)]
columns = ["Name", "Age"]
df = spark.createDataFrame(data, columns)
df.show()

# %%
spark.createDataFrame([("Alice", 29)], ["Name", "Age"]).show()

# %% [markdown]
# ### Importantly: To release resources

# %%
spark.stop()
